# %%
import numpy as np 
import pandas as pd 
import os

# %%
import keras
from keras.models import Sequential
from keras.layers import Conv2D,Flatten,Dense,MaxPooling2D,Dropout
from sklearn.metrics import accuracy_score

# %%
import ipywidgets as widgets
import io
from PIL import Image
import tqdm
from sklearn.model_selection import train_test_split
import cv2
from sklearn.utils import shuffle
import tensorflow as tf

# %%
# !pip install mplcyberpunk
# Out:
# Requirement already satisfied: mplcyberpunk in /opt/conda/lib/python3.10/site-packages (0.7.1)
# Requirement already satisfied: matplotlib in /opt/conda/lib/python3.10/site-packages (from mplcyberpunk) (3.7.5)
# Requirement already satisfied: contourpy>=1.0.1 in /opt/conda/lib/python3.10/site-packages (from matplotlib->mplcyberpunk) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in /opt/conda/lib/python3.10/site-packages (from matplotlib->mplcyberpunk) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /opt/conda/lib/python3.10/site-packages (from matplotlib->mplcyberpunk) (4.47.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /opt/conda/lib/python3.10/site-packages (from matplotlib->mplcyberpunk) (1.4.5)
# Requirement already satisfied: numpy<2,>=1.20 in /opt/conda/lib/python3.10/site-packages (from matplotlib->mplcyberpunk) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in /opt/conda/lib/python3.10/site-packages (from matplotlib->mplcyberpunk) (21.3)
# Requirement already satisfied: pillow>=6.2.0 in /opt/conda/lib/python3.10/site-packages (from matplotlib->mplcyberpunk) (9.5.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /opt/conda/lib/python3.10/site-packages (from matplotlib->mplcyberpunk) (3.1.1)
# Requirement already satisfied: python-dateutil>=2.7 in /opt/conda/lib/python3.10/site-packages (from matplotlib->mplcyberpunk) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in /opt/conda/lib/python3.10/site-packages (from python-dateutil>=2.7->matplotlib->mplcyberpunk) (1.16.0)

# %%
import os
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import mplcyberpunk

import cv2
import tensorflow as tf
from sklearn.utils import shuffle
from sklearn.model_selection import train_test_split
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import GlobalMaxPooling2D,GlobalAveragePooling2D, Dropout, Dense, BatchNormalization
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau, TensorBoard, ModelCheckpoint
from sklearn.metrics import classification_report,confusion_matrix
from tqdm import tqdm

# %%
X_train = []
Y_train = []
image_size = 150
labels = ['glioma_tumor','meningioma_tumor','no_tumor','pituitary_tumor']
for i in labels:
    folderPath = os.path.join('../input/brain-tumor-classification-mri/Training',i)
    for j in os.listdir(folderPath):
        img = cv2.imread(os.path.join(folderPath,j))
        img = cv2.resize(img,(image_size,image_size))
        X_train.append(img)
        Y_train.append(i)
        
for i in labels:
    folderPath = os.path.join('../input/brain-tumor-classification-mri/Testing',i)
    for j in os.listdir(folderPath):
        img = cv2.imread(os.path.join(folderPath,j))
        img = cv2.resize(img,(image_size,image_size))
        X_train.append(img)
        Y_train.append(i)

X_train = np.array(X_train)
Y_train = np.array(Y_train)

# %%
X_train,Y_train = shuffle(X_train,Y_train,random_state=101)
X_train.shape

# %%
X_train,X_test,y_train,y_test = train_test_split(X_train,Y_train,test_size=0.1,random_state=101)

# %%
y_train_new = []
for i in y_train:
    y_train_new.append(labels.index(i))
y_train=y_train_new
y_train = tf.keras.utils.to_categorical(y_train)

y_test_new = []
for i in y_test:
    y_test_new.append(labels.index(i))
y_test=y_test_new
y_test = tf.keras.utils.to_categorical(y_test)

# %%
model = Sequential()
model.add(Conv2D(32,(3,3),activation = 'relu',input_shape=(150,150,3)))
model.add(Conv2D(64,(3,3),activation='relu'))
model.add(MaxPooling2D(2,2))
model.add(Dropout(0.3))
model.add(Conv2D(64,(3,3),activation='relu'))
model.add(Conv2D(64,(3,3),activation='relu'))
model.add(Dropout(0.3))
model.add(MaxPooling2D(2,2))
model.add(Dropout(0.3))
model.add(Conv2D(128,(3,3),activation='relu'))
model.add(Conv2D(128,(3,3),activation='relu'))
model.add(Conv2D(128,(3,3),activation='relu'))
model.add(MaxPooling2D(2,2))
model.add(Dropout(0.3))
model.add(Conv2D(128,(3,3),activation='relu'))
model.add(Conv2D(256,(3,3),activation='relu'))
model.add(MaxPooling2D(2,2))
model.add(Dropout(0.3))
model.add(Flatten())
model.add(Dense(512,activation = 'relu'))
model.add(Dense(512,activation = 'relu'))
model.add(Dropout(0.3))
model.add(Dense(4,activation='softmax'))
# Out:
# /opt/conda/lib/python3.10/site-packages/keras/src/layers/convolutional/base_conv.py:99: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(

# %%
model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv2d (Conv2D)                 │ (None, 148, 148, 32)   │           896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_1 (Conv2D)               │ (None, 146, 146, 64)   │        18,496 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d (MaxPooling2D)    │ (None, 73, 73, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 73, 73, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_2 (Conv2D)               │ (None, 71, 71, 64)     │        36,928 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_3 (Conv2D)               │ (None, 69, 69, 64)     │        36,928 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 69, 69, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_1 (MaxPooling2D)  │ (None, 34, 34, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_2 (Dropout)             │ (None, 34, 34, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_4 (Conv2D)               │ (None, 32, 32, 128)    │        73,856 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_5 (Conv2D)               │ (None, 30, 30, 128)    │       147,584 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_6 (Conv2D)               │ (None, 28, 28, 128)    │       147,584 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_2 (MaxPooling2D)  │ (None, 14, 14, 128)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_3 (Dropout)             │ (None, 14, 14, 128)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_7 (Conv2D)               │ (None, 12, 12, 128)    │       147,584 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_8 (Conv2D)               │ (None, 10, 10, 256)    │       295,168 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_3 (MaxPooling2D)  │ (None, 5, 5, 256)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_4 (Dropout)             │ (None, 5, 5, 256)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten (Flatten)               │ (None, 6400)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 512)            │     3,277,312 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 512)            │       262,656 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_5 (Dropout)             │ (None, 512)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 4)              │         2,052 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 4,447,044 (16.96 MB)
#  Trainable params: 4,447,044 (16.96 MB)
#  Non-trainable params: 0 (0.00 B)

# %%
model.compile(loss='categorical_crossentropy',optimizer='Adam',metrics=['accuracy'])

# %%
history = model.fit(X_train,y_train,epochs=20,validation_split=0.1)
# Out:
# Epoch 1/20
#  2/83 ━━━━━━━━━━━━━━━━━━━━ 6s 86ms/step - accuracy: 0.2578 - loss: 20.7932
# W0000 00:00:1716396133.201350     101 graph_launch.cc:671] Fallback to op-by-op mode because memset node breaks graph update
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 195ms/step - accuracy: 0.2618 - loss: 4.0799
# W0000 00:00:1716396149.198599     100 graph_launch.cc:671] Fallback to op-by-op mode because memset node breaks graph update
# W0000 00:00:1716396150.033255     100 graph_launch.cc:671] Fallback to op-by-op mode because memset node breaks graph update
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 31s 212ms/step - accuracy: 0.2620 - loss: 4.0553 - val_accuracy: 0.2789 - val_loss: 1.3647
# Epoch 2/20
#  2/83 ━━━━━━━━━━━━━━━━━━━━ 5s 68ms/step - accuracy: 0.2500 - loss: 1.3414
# W0000 00:00:1716396150.663020     101 graph_launch.cc:671] Fallback to op-by-op mode because memset node breaks graph update
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 6s 69ms/step - accuracy: 0.2885 - loss: 1.3603 - val_accuracy: 0.2993 - val_loss: 1.4070
# Epoch 3/20
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 6s 69ms/step - accuracy: 0.3705 - loss: 1.3181 - val_accuracy: 0.5068 - val_loss: 1.1114
# Epoch 4/20
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 6s 70ms/step - accuracy: 0.5057 - loss: 1.0962 - val_accuracy: 0.5952 - val_loss: 0.9313
# Epoch 5/20
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 6s 69ms/step - accuracy: 0.6103 - loss: 0.8812 - val_accuracy: 0.5782 - val_loss: 0.8693
# Epoch 6/20
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 6s 69ms/step - accuracy: 0.6531 - loss: 0.8249 - val_accuracy: 0.6463 - val_loss: 0.7657
# Epoch 7/20
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 6s 68ms/step - accuracy: 0.7137 - loss: 0.6884 - val_accuracy: 0.7551 - val_loss: 0.5886
# Epoch 8/20
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 6s 68ms/step - accuracy: 0.7375 - loss: 0.6354 - val_accuracy: 0.6973 - val_loss: 0.5953
# Epoch 9/20
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 6s 68ms/step - accuracy: 0.7834 - loss: 0.5147 - val_accuracy: 0.7959 - val_loss: 0.5294
# Epoch 10/20
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 6s 67ms/step - accuracy: 0.8205 - loss: 0.4437 - val_accuracy: 0.8333 - val_loss: 0.4777
# Epoch 11/20
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 6s 67ms/step - accuracy: 0.8415 - loss: 0.3864 - val_accuracy: 0.8333 - val_loss: 0.3993
# Epoch 12/20
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 6s 67ms/step - accuracy: 0.8882 - loss: 0.3101 - val_accuracy: 0.8571 - val_loss: 0.3805
# Epoch 13/20
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 6s 67ms/step - accuracy: 0.8889 - loss: 0.2817 - val_accuracy: 0.8367 - val_loss: 0.3938
# Epoch 14/20
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 6s 67ms/step - accuracy: 0.9108 - loss: 0.2350 - val_accuracy: 0.8776 - val_loss: 0.3339
# Epoch 15/20
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 6s 68ms/step - accuracy: 0.9181 - loss: 0.2352 - val_accuracy: 0.8469 - val_loss: 0.4305
# Epoch 16/20
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 6s 68ms/step - accuracy: 0.9176 - loss: 0.2034 - val_accuracy: 0.8946 - val_loss: 0.2873
# Epoch 17/20
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 6s 68ms/step - accuracy: 0.9237 - loss: 0.2182 - val_accuracy: 0.8707 - val_loss: 0.3374
# Epoch 18/20
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 6s 68ms/step - accuracy: 0.9480 - loss: 0.1414 - val_accuracy: 0.8946 - val_loss: 0.3024
# Epoch 19/20
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 6s 68ms/step - accuracy: 0.9544 - loss: 0.1372 - val_accuracy: 0.8946 - val_loss: 0.3267
# Epoch 20/20
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 6s 68ms/step - accuracy: 0.9520 - loss: 0.1266 - val_accuracy: 0.8707 - val_loss: 0.3296

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Plotting training and validation loss
plt.figure(figsize=(12, 5))

plt.subplot(1, 2, 1)
plt.plot(history.history['loss'], label='Train Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.title('Training and Validation Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.grid(True)
mplcyberpunk.make_lines_glow()

# Plotting training and validation accuracy
plt.subplot(1, 2, 2)
plt.plot(history.history['accuracy'], label='Train Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.title('Training and Validation Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()
plt.grid(True)
mplcyberpunk.make_lines_glow()

plt.tight_layout()
plt.show()

# %%
y_true_test = np.argmax(y_test, axis=1)
y_pred_test = np.argmax(model.predict(X_test), axis=1) 

heatmap = sns.heatmap(confusion_matrix(y_true_test,y_pred_test), annot=True, fmt='d', cmap='Blues_r',
                      xticklabels=labels, yticklabels=labels)
plt.title('Confusion Matrix')
plt.xlabel('Predicted Label')
plt.ylabel('True Label')
plt.show()
# Out:
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step

# %%
#labels = ['glioma_tumor','meningioma_tumor','no_tumor','pituitary_tumor']
img = cv2.imread('../input/brain-tumor-classification-mri/Testing/glioma_tumor/image(20).jpg')
img = cv2.resize(img,(150,150))
img_array = np.array(img)
img_array.shape
# Out:
# (150, 150, 3)

# %%
img_array = img_array.reshape(1,150,150,3)
img_array.shape
# Out:
# (1, 150, 150, 3)

# %%
a=model.predict(img_array)
indices = a.argmax()
indices
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
# 0

# %%
model.save('CNN_BRAIN.h5')

# %%
from tensorflow.keras.models import load_model
m2=load_model('/kaggle/working/CNN_BRAIN.h5')

# %%
img = cv2.imread('/kaggle/input/brain-tumor-classification-mri/Training/no_tumor/5.jpg')
img = cv2.resize(img,(150,150))
img_array = np.array(img)
img_array.shape

img_array = img_array.reshape(1,150,150,3)
img_array.shape

a=m2.predict(img_array)
indices = a.argmax()
#indices
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 511ms/step

# %% [markdown]
# # RESnet

# %%
# Load the ResNet101 model pretrained on ImageNet without the top layers
resnet = tf.keras.applications.ResNet101(weights='imagenet', include_top=False,
                                         input_shape=(image_size, image_size, 3))

# Build the custom model on top of the ResNet101 base

model2 = resnet.output
model2 = tf.keras.layers.GlobalAveragePooling2D()(model2)
model2 = tf.keras.layers.Dropout(rate=0.5)(model2)
model2 = tf.keras.layers.Dense(4,activation='softmax')(model2)
model2 = tf.keras.models.Model(inputs=resnet.input, outputs = model2)

# Compile the model
model2.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/resnet/resnet101_weights_tf_dim_ordering_tf_kernels_notop.h5
# 171446536/171446536 ━━━━━━━━━━━━━━━━━━━━ 1s 0us/step

# %%
model2.summary()

# %%
# Tensorboard callback for logging training metrics
tensorboard = TensorBoard(log_dir='logs')

# Modelcheckpoint callback to save the best model 
checkpoint = ModelCheckpoint("efficientnetB0.keras", monitor="val_accuracy",
                             save_best_only=True, verbose=1)

# ReduceLROnPlateau callback to reduce learning rate if validation accuracy plateaus
reduce_lr = ReduceLROnPlateau(monitor='val_accuracy', factor=0.1, patience=2, 
                              min_delta=0.0001, verbose=1)

# %%
history = model2.fit(X_train,y_train,validation_split=0.1, epochs =15, verbose=1, batch_size=32,
                   callbacks=[tensorboard,checkpoint,reduce_lr])
# Out:
# Epoch 1/15
# W0000 00:00:1716395176.623587     101 graph_launch.cc:671] Fallback to op-by-op mode because memset node breaks graph update
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.5521 - loss: 1.5059
# W0000 00:00:1716395262.772540     101 graph_launch.cc:671] Fallback to op-by-op mode because memset node breaks graph update
# W0000 00:00:1716395270.577726     101 graph_launch.cc:671] Fallback to op-by-op mode because memset node breaks graph update
# Epoch 1: val_accuracy improved from -inf to 0.27891, saving model to efficientnetB0.keras
# W0000 00:00:1716395277.076542     100 graph_launch.cc:671] Fallback to op-by-op mode because memset node breaks graph update
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 235s 1s/step - accuracy: 0.5520 - loss: 1.5043 - val_accuracy: 0.2789 - val_loss: 3189491.0000 - learning_rate: 0.0010
# Epoch 2/15
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 283ms/step - accuracy: 0.6364 - loss: 0.9204
# Epoch 2: val_accuracy improved from 0.27891 to 0.36735, saving model to efficientnetB0.keras
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 28s 331ms/step - accuracy: 0.6367 - loss: 0.9195 - val_accuracy: 0.3673 - val_loss: 294.2807 - learning_rate: 0.0010
# Epoch 3/15
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 278ms/step - accuracy: 0.7542 - loss: 0.6726
# Epoch 3: val_accuracy improved from 0.36735 to 0.71088, saving model to efficientnetB0.keras
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 27s 323ms/step - accuracy: 0.7542 - loss: 0.6723 - val_accuracy: 0.7109 - val_loss: 1.2642 - learning_rate: 0.0010
# Epoch 4/15
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 277ms/step - accuracy: 0.8296 - loss: 0.4381
# Epoch 4: val_accuracy improved from 0.71088 to 0.79932, saving model to efficientnetB0.keras
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 27s 323ms/step - accuracy: 0.8297 - loss: 0.4379 - val_accuracy: 0.7993 - val_loss: 0.6029 - learning_rate: 0.0010
# Epoch 5/15
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 280ms/step - accuracy: 0.9043 - loss: 0.2763
# Epoch 5: val_accuracy did not improve from 0.79932
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 24s 290ms/step - accuracy: 0.9041 - loss: 0.2766 - val_accuracy: 0.4830 - val_loss: 3.9670 - learning_rate: 0.0010
# Epoch 6/15
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 279ms/step - accuracy: 0.9162 - loss: 0.2365
# Epoch 6: val_accuracy did not improve from 0.79932
#
# Epoch 6: ReduceLROnPlateau reducing learning rate to 0.00010000000474974513.
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 24s 289ms/step - accuracy: 0.9161 - loss: 0.2367 - val_accuracy: 0.7585 - val_loss: 0.8482 - learning_rate: 0.0010
# Epoch 7/15
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 278ms/step - accuracy: 0.9657 - loss: 0.1156
# Epoch 7: val_accuracy improved from 0.79932 to 0.95238, saving model to efficientnetB0.keras
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 27s 322ms/step - accuracy: 0.9657 - loss: 0.1155 - val_accuracy: 0.9524 - val_loss: 0.1549 - learning_rate: 1.0000e-04
# Epoch 8/15
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 278ms/step - accuracy: 0.9793 - loss: 0.0816
# Epoch 8: val_accuracy improved from 0.95238 to 0.96259, saving model to efficientnetB0.keras
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 27s 324ms/step - accuracy: 0.9793 - loss: 0.0816 - val_accuracy: 0.9626 - val_loss: 0.1194 - learning_rate: 1.0000e-04
# Epoch 9/15
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 279ms/step - accuracy: 0.9938 - loss: 0.0390
# Epoch 9: val_accuracy improved from 0.96259 to 0.96939, saving model to efficientnetB0.keras
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 27s 323ms/step - accuracy: 0.9938 - loss: 0.0391 - val_accuracy: 0.9694 - val_loss: 0.1025 - learning_rate: 1.0000e-04
# Epoch 10/15
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 278ms/step - accuracy: 0.9897 - loss: 0.0412
# Epoch 10: val_accuracy did not improve from 0.96939
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 24s 288ms/step - accuracy: 0.9897 - loss: 0.0411 - val_accuracy: 0.9626 - val_loss: 0.0984 - learning_rate: 1.0000e-04
# Epoch 11/15
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 279ms/step - accuracy: 0.9934 - loss: 0.0327
# Epoch 11: val_accuracy did not improve from 0.96939
#
# Epoch 11: ReduceLROnPlateau reducing learning rate to 1.0000000474974514e-05.
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 24s 288ms/step - accuracy: 0.9934 - loss: 0.0327 - val_accuracy: 0.9558 - val_loss: 0.1027 - learning_rate: 1.0000e-04
# Epoch 12/15
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 279ms/step - accuracy: 0.9929 - loss: 0.0309
# Epoch 12: val_accuracy did not improve from 0.96939
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 24s 289ms/step - accuracy: 0.9929 - loss: 0.0309 - val_accuracy: 0.9524 - val_loss: 0.0965 - learning_rate: 1.0000e-05
# Epoch 13/15
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 278ms/step - accuracy: 0.9970 - loss: 0.0201
# Epoch 13: val_accuracy did not improve from 0.96939
#
# Epoch 13: ReduceLROnPlateau reducing learning rate to 1.0000000656873453e-06.
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 24s 288ms/step - accuracy: 0.9970 - loss: 0.0201 - val_accuracy: 0.9524 - val_loss: 0.0939 - learning_rate: 1.0000e-05
# Epoch 14/15
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 278ms/step - accuracy: 0.9940 - loss: 0.0266
# Epoch 14: val_accuracy did not improve from 0.96939
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 24s 288ms/step - accuracy: 0.9940 - loss: 0.0266 - val_accuracy: 0.9524 - val_loss: 0.0940 - learning_rate: 1.0000e-06
# Epoch 15/15
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 278ms/step - accuracy: 0.9967 - loss: 0.0212
# Epoch 15: val_accuracy did not improve from 0.96939
#
# Epoch 15: ReduceLROnPlateau reducing learning rate to 1.0000001111620805e-07.
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 24s 288ms/step - accuracy: 0.9967 - loss: 0.0212 - val_accuracy: 0.9524 - val_loss: 0.0937 - learning_rate: 1.0000e-06

# %%
# Plotting training and validation loss
plt.figure(figsize=(12, 5))

plt.subplot(1, 2, 1)
plt.plot(history.history['loss'], label='Train Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.title('Training and Validation Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.grid(True)
mplcyberpunk.make_lines_glow()

# Plotting training and validation accuracy
plt.subplot(1, 2, 2)
plt.plot(history.history['accuracy'], label='Train Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.title('Training and Validation Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()
plt.grid(True)
mplcyberpunk.make_lines_glow()

plt.tight_layout()
plt.show()

# %%
y_true_test = np.argmax(y_test, axis=1)
y_pred_test = np.argmax(model.predict(X_test), axis=1) 

heatmap = sns.heatmap(confusion_matrix(y_true_test,y_pred_test), annot=True, fmt='d', cmap='Blues_r',
                      xticklabels=labels, yticklabels=labels)
plt.title('Confusion Matrix')
plt.xlabel('Predicted Label')
plt.ylabel('True Label')
plt.show()
# Out:
#  9/11 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# W0000 00:00:1716395634.840358     101 graph_launch.cc:671] Fallback to op-by-op mode because memset node breaks graph update
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 3s 282ms/step
# W0000 00:00:1716395637.659223     102 graph_launch.cc:671] Fallback to op-by-op mode because memset node breaks graph update

# %%
print(classification_report(y_true_test,y_pred_test))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.69      0.89      0.78        93
#            1       0.92      0.59      0.72        95
#            2       0.84      0.81      0.82        52
#            3       0.90      0.99      0.94        87
#
#     accuracy                           0.82       327
#    macro avg       0.84      0.82      0.82       327
# weighted avg       0.84      0.82      0.81       327

# %%
random_index = np.random.randint(0, len(X_test))
random_img = X_test[random_index]  
predictions = model.predict(random_img.reshape(1, 150, 150, 3))  # Reshape and preprocess the image

# Interpret the model's predictions
predicted_class = np.argmax(predictions)  # Get the index of the class with the highest probability
predicted_label = labels[predicted_class]  # Convert class to label
confidence = predictions[0][predicted_class]

actual_index = y_test[random_index]  # Get the one-hot encoded actual class
actual_class = np.argmax(actual_index)  
actual_label = labels[actual_class]  

# Display the image and prediction information
print(f"\033[94mPredicted label: {predicted_label}\033[0m \n\033[92mActual label: {actual_label}\033[0m \n\033[93mConfidence: {confidence*100:.2f}%\033[0m\n")
plt.figure(figsize = (3,3))
plt.imshow(random_img)
plt.axis('off')  
plt.show()
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# Predicted label: glioma_tumor
# Actual label: glioma_tumor
# Confidence: 99.69%

# %%
model2.save("Resnet_BRAIN.h5")

# %% [markdown]
# # Xception CNN

# %%
xception = tf.keras.applications.Xception(weights='imagenet', include_top=False,
                                          input_shape=(image_size, image_size, 3))

# Build the custom model on top of the Xception base
model = xception.output
model = tf.keras.layers.GlobalAveragePooling2D()(model)
model = tf.keras.layers.Dense(1536,activation='relu')(model)
model = tf.keras.layers.Dropout(rate=0.5)(model)
model = tf.keras.layers.Dense(4,activation='softmax')(model)
model = tf.keras.models.Model(inputs=xception.input, outputs = model)

# Compile the model
model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/xception/xception_weights_tf_dim_ordering_tf_kernels_notop.h5
# 83683744/83683744 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step

# %%
model.summary()

# %%
# Tensorboard callback for logging training metrics
tensorboard = TensorBoard(log_dir='logs')

# Modelcheckpoint callback to save the best model 
checkpoint = ModelCheckpoint("efficientnetB0.keras", monitor="val_accuracy",
                             save_best_only=True, verbose=1)

# ReduceLROnPlateau callback to reduce learning rate if validation accuracy plateaus
reduce_lr = ReduceLROnPlateau(monitor='val_accuracy', factor=0.1, patience=2, 
                              min_delta=0.0001, verbose=1)

# %%
history = model.fit(X_train,y_train,validation_split=0.1, epochs =12, verbose=1, batch_size=32,
                   callbacks=[tensorboard,checkpoint,reduce_lr])
# Out:
# Epoch 1/12
# W0000 00:00:1716395706.803043     102 graph_launch.cc:671] Fallback to op-by-op mode because memset node breaks graph update
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 599ms/step - accuracy: 0.6837 - loss: 0.8795
# W0000 00:00:1716395756.507685     102 graph_launch.cc:671] Fallback to op-by-op mode because memset node breaks graph update
# W0000 00:00:1716395759.908589     102 graph_launch.cc:671] Fallback to op-by-op mode because memset node breaks graph update
# Epoch 1: val_accuracy improved from -inf to 0.36735, saving model to efficientnetB0.keras
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 124s 715ms/step - accuracy: 0.6850 - loss: 0.8759 - val_accuracy: 0.3673 - val_loss: 14.4183 - learning_rate: 0.0010
# Epoch 2/12
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 191ms/step - accuracy: 0.9003 - loss: 0.3317
# Epoch 2: val_accuracy improved from 0.36735 to 0.81293, saving model to efficientnetB0.keras
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 18s 215ms/step - accuracy: 0.9003 - loss: 0.3318 - val_accuracy: 0.8129 - val_loss: 1.8106 - learning_rate: 0.0010
# Epoch 3/12
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 196ms/step - accuracy: 0.9363 - loss: 0.2197
# Epoch 3: val_accuracy improved from 0.81293 to 0.92177, saving model to efficientnetB0.keras
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 18s 219ms/step - accuracy: 0.9363 - loss: 0.2199 - val_accuracy: 0.9218 - val_loss: 0.2660 - learning_rate: 0.0010
# Epoch 4/12
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 192ms/step - accuracy: 0.9559 - loss: 0.1362
# Epoch 4: val_accuracy did not improve from 0.92177
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 16s 198ms/step - accuracy: 0.9558 - loss: 0.1365 - val_accuracy: 0.7959 - val_loss: 1.7108 - learning_rate: 0.0010
# Epoch 5/12
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 190ms/step - accuracy: 0.9656 - loss: 0.1294
# Epoch 5: val_accuracy did not improve from 0.92177
#
# Epoch 5: ReduceLROnPlateau reducing learning rate to 0.00010000000474974513.
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 16s 196ms/step - accuracy: 0.9656 - loss: 0.1293 - val_accuracy: 0.7687 - val_loss: 0.9882 - learning_rate: 0.0010
# Epoch 6/12
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 190ms/step - accuracy: 0.9718 - loss: 0.0977
# Epoch 6: val_accuracy improved from 0.92177 to 0.95238, saving model to efficientnetB0.keras
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 18s 213ms/step - accuracy: 0.9718 - loss: 0.0975 - val_accuracy: 0.9524 - val_loss: 0.2349 - learning_rate: 1.0000e-04
# Epoch 7/12
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 191ms/step - accuracy: 0.9932 - loss: 0.0286
# Epoch 7: val_accuracy improved from 0.95238 to 0.95918, saving model to efficientnetB0.keras
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 18s 215ms/step - accuracy: 0.9932 - loss: 0.0286 - val_accuracy: 0.9592 - val_loss: 0.1649 - learning_rate: 1.0000e-04
# Epoch 8/12
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 192ms/step - accuracy: 0.9935 - loss: 0.0192
# Epoch 8: val_accuracy did not improve from 0.95918
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 16s 198ms/step - accuracy: 0.9935 - loss: 0.0192 - val_accuracy: 0.9558 - val_loss: 0.1575 - learning_rate: 1.0000e-04
# Epoch 9/12
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 192ms/step - accuracy: 0.9935 - loss: 0.0214
# Epoch 9: val_accuracy did not improve from 0.95918
#
# Epoch 9: ReduceLROnPlateau reducing learning rate to 1.0000000474974514e-05.
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 16s 198ms/step - accuracy: 0.9935 - loss: 0.0214 - val_accuracy: 0.9592 - val_loss: 0.1482 - learning_rate: 1.0000e-04
# Epoch 10/12
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 191ms/step - accuracy: 0.9978 - loss: 0.0083
# Epoch 10: val_accuracy improved from 0.95918 to 0.96599, saving model to efficientnetB0.keras
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 18s 214ms/step - accuracy: 0.9978 - loss: 0.0083 - val_accuracy: 0.9660 - val_loss: 0.1515 - learning_rate: 1.0000e-05
# Epoch 11/12
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 191ms/step - accuracy: 0.9974 - loss: 0.0097
# Epoch 11: val_accuracy did not improve from 0.96599
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 16s 197ms/step - accuracy: 0.9974 - loss: 0.0097 - val_accuracy: 0.9660 - val_loss: 0.1544 - learning_rate: 1.0000e-05
# Epoch 12/12
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 191ms/step - accuracy: 0.9971 - loss: 0.0094
# Epoch 12: val_accuracy did not improve from 0.96599
#
# Epoch 12: ReduceLROnPlateau reducing learning rate to 1.0000000656873453e-06.
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 16s 197ms/step - accuracy: 0.9971 - loss: 0.0094 - val_accuracy: 0.9660 - val_loss: 0.1545 - learning_rate: 1.0000e-05

# %%
# Plotting training and validation loss
plt.figure(figsize=(12, 5))

plt.subplot(1, 2, 1)
plt.plot(history.history['loss'], label='Train Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.title('Training and Validation Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.grid(True)
mplcyberpunk.make_lines_glow()

# Plotting training and validation accuracy
plt.subplot(1, 2, 2)
plt.plot(history.history['accuracy'], label='Train Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.title('Training and Validation Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()
plt.grid(True)
mplcyberpunk.make_lines_glow()

plt.tight_layout()
plt.show()

# %%
y_true_test = np.argmax(y_test, axis=1)
y_pred_test = np.argmax(model.predict(X_test), axis=1) 

heatmap = sns.heatmap(confusion_matrix(y_true_test,y_pred_test), annot=True, fmt='d', cmap='Blues_r',
                      xticklabels=labels, yticklabels=labels)
plt.title('Confusion Matrix')
plt.xlabel('Predicted Label')
plt.ylabel('True Label')
plt.show()
# Out:
#  4/11 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step
# W0000 00:00:1716395957.752171     100 graph_launch.cc:671] Fallback to op-by-op mode because memset node breaks graph update
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 9s 600ms/step

# %%
print(classification_report(y_true_test,y_pred_test))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.98      0.94      0.96        93
#            1       0.96      0.96      0.96        95
#            2       0.98      1.00      0.99        52
#            3       0.97      1.00      0.98        87
#
#     accuracy                           0.97       327
#    macro avg       0.97      0.97      0.97       327
# weighted avg       0.97      0.97      0.97       327

# %%
random_index = np.random.randint(0, len(X_test))
random_img = X_test[random_index]  
predictions = model.predict(random_img.reshape(1, 150, 150, 3))  # Reshape and preprocess the image

# Interpret the model's predictions
predicted_class = np.argmax(predictions)  # Get the index of the class with the highest probability
predicted_label = labels[predicted_class]  # Convert class to label
confidence = predictions[0][predicted_class]

actual_index = y_test[random_index]  # Get the one-hot encoded actual class
actual_class = np.argmax(actual_index)  
actual_label = labels[actual_class] 

# Display the image and prediction information
print(f"\033[94mPredicted label: {predicted_label}\033[0m \n\033[92mActual label: {actual_label}\033[0m \n\033[93mConfidence: {confidence*100:.2f}%\033[0m\n")
plt.figure(figsize = (3,3))
plt.imshow(random_img)
plt.axis('off')  
plt.show()
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 4s 4s/step
# Predicted label: meningioma_tumor
# Actual label: meningioma_tumor
# Confidence: 99.95%

# %%
model.save('Xception_BRAIN.h5')
